# %% [markdown]
# # <center> Lesson 2: crawler </center>

# %% [markdown]
# # 本章目標
# 抓取網站上的資料並整理輸出抓取的資料

# %% [markdown]
# # Outline
# > 1. Introduction to Crawler
# > 2. Introduction to Website
# > 3. Crawl Recipe Website
# > 4. A little summary
# > 5. Practice

# %% [markdown]
# ![recipes](res/website.png)

# %% [markdown]
# 食譜這麼多，有沒有辦法把他們都抓下來呢？

# %% [markdown]
# # 1. Introduction to Crawler
# ### Crawler:
# * 網路爬蟲程式
# * 可以幫助我們自動化的去抓取網頁結構相同的網頁

# %% [markdown]
# ### 好用的自動化抓取工具: [httptrack](https://www.httrack.com/)
# * 抓小量資料很方便
# * 只要輸入一個root url，程式就會自動尋找其他的url去抓
#
# ### python知名的crawler framwork: [scrapy](http://scrapy.org/)
# * 實作了許多很常用的小細節
# * 上手需要一些練習，需要熟悉框架才能知道要定義哪些檔案

# %% [markdown]
# ### 套件安裝
# * 下載網頁的好用套件: [requests](http://docs.python-requests.org/en/latest/user/quickstart/)
# > sudo pip install requests
# * 解析網頁的好用套件: [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# > sudo pip install beautifulsoup4

# %% [markdown]
# # Attention Please!!
# 在使用crawler時，請千萬注意不要一口氣抓取過多的網頁 <br>
# 這樣子做相當於對對方的server進行惡意攻擊！！ <br>
# 也可能會導致你的IP被BAN掉而無法繼續瀏覽該網站！！ <br>
#
# 一種解決方法是使用delay的機制來避免過度頻繁存取 <br>
# 另外設置每小時瀏覽量也是一個做法 <br>
# 此外，如果有多組ip可以使用，將工作分配給各IP去執行也是個做法 <br>

# %% [markdown]
# # 2. Introduction to Website

# %% [markdown]
# # What is website?

# %% [markdown]
# # This is a website.
# ![recipes](res/website.png)

# %% [markdown]
# # This is a webiste, too.
#
# ![recipes](res/website_code.png)

# %% [markdown]
# # 網站基本架構
# 一般來說，網站分成<b>前端(fron-end)</b>與<b>後端(back-end)</b>
#
# ![](res/simple_website_architecher.jpg)

# %% [markdown]
# # Html
# html是網頁的主體，由tag組成，定義了網頁的內容與框架

# %%
from IPython.core.display import HTML

# %%
HTML("""
<html>
    <body>
        <button class="btn1">hello</button><button class="btn2"> world</button>
        <p> the world is beautiful</p>
    <body>
</html>""")
# Out:
# <html>
#     <body>
#         <button class="btn1">hello</button><button class="btn2"> world</button>
#         <p> the world is beautiful</p>
#     <body>
# </html>

# %% [markdown]
# # css
# css詮釋了網頁的框架，我們可以透過css定義框架應該怎樣呈現給user

# %%
css_file = """ p#pdemo{ color: orange; } """
open("demo.css","w").write(css_file)

# %%
HTML("""
<html>
    <head> <link rel="stylesheet" href="demo.css"> </head>
    <body>
        <button class="btn1">hello</button><button class="btn2"> world</button>
        <p id="pdemo"> the world is beautiful</p>
    <body>
</html> """)
# Out:
# <html>
#     <head> <link rel="stylesheet" href="demo.css"> </head>
#     <body>
#         <button class="btn1">hello</button><button class="btn2"> world</button>
#         <p id="pdemo"> the world is beautiful</p>
#     <body>
# </html>

# %% [markdown]
# # Javascript
# * javascript讓user可以跟網頁進行更豐富的互動
# * 不論是動畫的效果，或甚至是跟server進行溝通，都可以透過js完成
# * 甚至還有js的套件可以做到更多更豐富的效果，像是有名的[node.js](https://nodejs.org/en/)

# %%
HTML("""
<html>
    <head> <link rel="stylesheet" href="demo.css"> 
        <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
        <script>
        $(document).ready(function(){
            $(".btn1").click(function(){ 
                $("p.jdemo").animate({wordSpacing: "+=15px"}); });
            $(".btn2").click(function(){ 
                $("p.jdemo").animate({wordSpacing: "-=15px"}); });
        });
        </script>
    </head>
    <body>
        <button class="btn1">hello</button><button class="btn2"> world</button>
        <p id="pdemo" class="jdemo"> the world is beautiful</p>
    <body>
</html> """)
# Out:
# <html>
#     <head> <link rel="stylesheet" href="demo.css">
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#         <script>
#         $(document).ready(function(){
#             $(".btn1").click(function(){
#                 $("p.jdemo").animate({wordSpacing: "+=15px"}); });
#             $(".btn2").click(function(){
#                 $("p.jdemo").animate({wordSpacing: "-=15px"}); });
#         });
#         </script>
#     </head>
#     <body>
#         <button class="btn1">hello</button><button class="btn2"> world</button>
#         <p id="pdemo" class="jdemo"> the world is beautiful</p>
#     <body>
# </html>

# %% [markdown]
# # 3. Crawl Recipe Website
# ### 現在讓我們來抓取食譜網站吧！

# %% [markdown]
# ### 首先，先讓我們來試著抓一塊蛋糕吧！  [![recipes](res/cake.png)](http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub)

# %%
import requests
url = "http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub"
recipe = requests.get(url)
recipe_html = recipe.content
print repr(recipe_html[:500])
print repr(recipe_html[-500:])
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<!-- ARLOG SERVER: USSEAMOBILE32 LOCAL_IP: 192.168.5.121 MERCH_KEY: MerchData_4_1_1_8372_***_68 -->\r\n\r\n    <head>\r\n        <title>Black Magic Cake Recipe - Allrecipes.com</title>\r\n            <meta property="og:title" content="Black Magic Cake Recipe" />\r\n    \r\n        <meta property="og:site_name" content="Allrecipes" />\r\n        <meta charset="utf-8" />\r\n        <meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n            <meta id="metaDescri'
# 'n(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'placeholderDL\',\'GTM-MW2LG9\');</script>\r\n        <!-- End Google Tag Manager -->\r\n\r\n        <script type="text/javascript">_satellite.pageBottom(); // Initialize Adobe DTM</script>\r\n    </body>\r\n</html>\r\n'

# %% [markdown]
# # 等等，requests.get是啥呢？
# * get是一種傳輸協定，藉由網址可以向server傳遞一些參數 <br>
# 比方說 http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub <br>
# 傳遞了<i>internalSource</i>這個參數，其值為<i>staff</i> <br>
# 而<i>referringId</i>這個參數，其值為<i>79</i> <br><br>
#
# * 另外一種常見的傳遞方式為post <br>
# post傳遞的參數不會顯示在?後面 <br>
# 也因此這種傳遞方式比較安全！傳遞的量也比較大！

# %% [markdown]
# ### 接著讓我們將"食譜名稱"，"評分"，"評分人數"，"食材"，"烹煮時間"抓出來吧！
# ![recipes](res/extract_cake.jpg)

# %% [markdown]
# ### 但在抓之前...

# %% [markdown]
# # 我們要怎麼知道網頁上的什麼元素對應到html裡的哪裏啊？？

# %% [markdown]
# # chrome 開發者工具
# 按右鍵，選擇"檢查元素"
# 1. 點選搜尋
# 2. 選取想搜尋的元素
# 3. 查看對應的html tag
# ![](res/chrome.jpg)

# %% [markdown]
# # 現在我們找到tag了!
# ### 食譜名稱就藏在"< h1 class="recipe-summary__h1" itemprop="name">"這個tag中，但我們還必須確認他的唯一性
# 對網頁按右鍵，點選"檢視網頁原始碼"
# 搜尋"recipe-summary__h1"
#
# ![](res/chrome2.png)
#
# 我們可以看到搜尋結果只有一個，這代表這個tag確實只會用來顯示這個食譜名稱！

# %% [markdown]
# # 我們現在已經找到tag了，但是我們要怎麼用python去指定這個tag呢？

# %% [markdown]
# # DOM(Document Object Model) Tree
#
# ### 其實一個html檔案是可以表示成一個tree的
#
# ![](res/dom_tree.gif)
#
# ### 所以藉由將html網頁表示成tree，我們便可以對tree進行搜尋找出我們要的tag
# ### 像是使用xpath，或是css selector的方式

# %% [markdown]
# # Parse(頗析)html的一些好用套件:
# 1. beautiful soup <br>
#   - 可以使用tag搭配屬性的方式搜尋tag，也可以使用selector的方式指定某個位置的tag <br>
#   - 用搜尋的方式有可能會導致parse的速度較慢
# 2. pyquery <br>
#   - 可以使用selector的方式指定某個位置的tag
# 3. lxml <br>
#   - 使用xpath的方式指定某個位置的tag
#   - 但安裝上可能會比較容易遇到些困難

# %% [markdown]
# ### 為了方便起見，之後將會以beautiful soup為主來進行parse

# %% [markdown]
# # 現在我們有了分析的工具！
# ### 讓我們把"食譜名稱"，"評分"，"評分人數"，"食材"，"烹煮時間"抓出來吧！
#
# ![recipes](res/extract_cake.jpg)

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

def get_recipe_html(url):
    recipe = requests.get(url)
    recipe_html = recipe.content
    return recipe_html

def parse_a_recipe(url,recipe_html):
    parsed_data = {'url':url}
    soup = BeautifulSoup(recipe_html)
    parsed_data['id'] = int(soup.find("meta", property="fb:app_id").get("content"))
    parsed_data['recipe_name'] = soup.find('h1',class_="recipe-summary__h1").get_text()
    parsed_data['rating'] = float(soup.find('div',class_="rating-stars").get("data-ratingstars"))
    parsed_data['vote_number'] = int(soup.find('span',class_="review-count").get_text())
    parsed_data['ingredients'] = [ ingredient.get_text() for ingredient in soup.find_all("span",itemprop="ingredients") ]
    parsed_data['prep_time'] = soup.find("time", itemprop="prepTime").get("datetime")
    parsed_data['cook_time'] = soup.find("time", itemprop="cookTime").get("datetime")
    parsed_data['total_time'] = soup.find("time", itemprop="totalTime").get("datetime")
    return parsed_data

# %%
url = "http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub"
pprint( parse_a_recipe(url,get_recipe_html(url)) )
# Out:
# {'cook_time': 'PT35M',
#  'id': 66102450266,
#  'ingredients': [u'1 3/4 cups all-purpose flour',
#                  u'2 cups white sugar',
#                  u'3/4 cup unsweetened cocoa powder',
#                  u'2 teaspoons baking soda',
#                  u'1 teaspoon baking powder',
#                  u'1 teaspoon salt',
#                  u'2 eggs',
#                  u'1 cup strong brewed coffee',
#                  u'1 cup buttermilk',
#                  u'1/2 cup vegetable oil',
#                  u'1 teaspoon vanilla extract'],
#  'prep_time': 'PT15M',
#  'rating': 4.76773357391357,
#  'recipe_name': u'Black Magic Cake',
#  'total_time': 'PT1H',
#  'url': 'http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub',
#  'vote_number': 1786}

# %% [markdown]
# # 時間的格式好像有點難搞啊！
# 'PT35M' <br>
# 'PT15M' <br>
# 'PT1H' <br>

# %% [markdown]
# ### 有沒有辦法都轉成分鐘呢？

# %% [markdown]
# # Regular Expression
# 使用一套描述的方法，去描述形式上固定，但值不固定的pattern

# %%
import re
testing_case = [ 'PT1H35M' ,'PT15M' ,'PT1H' ]
for test in testing_case:
    hour = re.search("PT(.+)H",test)
    hour = int(hour.group(1)) if hour else 0
        
    minute = re.search("H(.+)M",test)
    minute = minute if minute else re.search("PT(.+)M",test)
    minute = int(minute.group(1)) if minute else 0
    
    total = hour*60+minute
    print "H: {0} M: {1:>2} Total: {2} mins".format(hour,minute,total)
# Out:
# H: 1 M: 35 Total: 95 mins
# H: 0 M: 15 Total: 15 mins
# H: 1 M:  0 Total: 60 mins

# %% [markdown]
# # 現在讓我們來把Parser修的更完整一點吧！
# * 加入re解析時間
# * 加入例外處理機制
# * 加上編碼轉換

# %%
import requests
import re
import traceback
from bs4 import BeautifulSoup
from pprint import pprint

def get_recipe_html(url):
    recipe = requests.get(url)
    recipe_html = recipe.content
    return recipe_html

def extract_time(t):
    if t != None :
        t = t.get("datetime")
        hour = re.search("PT(.+)H",t)
        hour = int(hour.group(1)) if hour else 0
        minute = re.search("H(.+)M",t)
        minute = minute if minute else re.search("PT(.+)M",t)
        minute = int(minute.group(1)) if minute else 0
        total = hour*60+minute
        return total
    else:
        return "NULL"

def parse_a_recipe(url,recipe_html):
    try:
        parsed_data = {'url':url}
        soup = BeautifulSoup(recipe_html)
        parsed_data['id'] = int(soup.find("meta", property="fb:app_id").get("content"))
        parsed_data['recipe_name'] = soup.find('h1',class_="recipe-summary__h1").get_text()
        parsed_data['rating'] = float(soup.find('div',class_="rating-stars").get("data-ratingstars"))
        parsed_data['vote_number'] = int(soup.find('span',class_="review-count").get_text())
        parsed_data['ingredients'] = [ ingredient.get_text() for ingredient in soup.find_all("span",itemprop="ingredients") ]
        parsed_data['prep_time'] = extract_time( soup.find("time", itemprop="prepTime") )
        parsed_data['cook_time'] = extract_time( soup.find("time", itemprop="cookTime") )
        parsed_data['total_time'] = extract_time( soup.find("time", itemprop="totalTime") )

        handle_encoding(parsed_data)
    except:
        print "url:{0}\n{1}".format(url,traceback.format_exc())
    
    return parsed_data

def handle_encoding(parsed_data):
    for k,v in parsed_data.items():
        if type(v) == type(u"unicode"):
            parsed_data[k] = v.encode("utf8",'ignore')
        if type(v) == type([]):
            for idx in xrange(len(v)):
                v[idx] = v[idx].encode("utf8",'ignore')

# %%
url = "http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub"
parsed_result = parse_a_recipe(url,get_recipe_html(url))
pprint( parsed_result )
# Out:
# {'cook_time': 35,
#  'id': 66102450266,
#  'ingredients': ['1 3/4 cups all-purpose flour',
#                  '2 cups white sugar',
#                  '3/4 cup unsweetened cocoa powder',
#                  '2 teaspoons baking soda',
#                  '1 teaspoon baking powder',
#                  '1 teaspoon salt',
#                  '2 eggs',
#                  '1 cup strong brewed coffee',
#                  '1 cup buttermilk',
#                  '1/2 cup vegetable oil',
#                  '1 teaspoon vanilla extract'],
#  'prep_time': 15,
#  'rating': 4.76773357391357,
#  'recipe_name': 'Black Magic Cake',
#  'total_time': 60,
#  'url': 'http://allrecipes.com/recipe/8372/black-magic-cake/?internalSource=staff%20pick&referringId=79&referringContentType=recipe%20hub',
#  'vote_number': 1786}

# %% [markdown]
# * 時間成功轉成了分鐘
# * 並且字串都已經變成utf8編碼

# %% [markdown]
# # 將資料輸出成csv
# * 將食譜的基本資料存成一個csv <br>
# * 食材的資料存成一個csv <br>
# * 兩個資料都存放id欄位，方便資料做對應<br>
# * 如果存放的值是字串，要加上引號！！

# %%
basic_info_order = ['id','recipe_name','rating','vote_number','prep_time','cook_time','total_time','url']
ingredient_info_order = ['id','ingredient']

def add_quote(text):
    return '"{0}"'.format(text) if type(text) == type('string') else str(text)

def output_csv(parsed_results):
    basic_writer = open( "basic_info.csv", 'w' )
    ingredient_writer = open( "ingredient_info.csv", 'w' )
    
    # write head
    basic_writer.write( '"{0}"\n'.format('","'.join(basic_info_order)) )
    ingredient_writer.write( '"{0}"\n'.format('","'.join(ingredient_info_order)) )
    
    # write content
    for result in parsed_results:
        basic_writer.write(','.join([ add_quote(result[order]) for order in basic_info_order ])+'\n')
        for igd in result['ingredients']:
            ingredient_writer.write('{id},"{igd}"\n'.format(id=result['id'],igd=igd))
    basic_writer.close()
    ingredient_writer.close()

# %%
output_csv([parsed_result])

# %%
import pandas as pd
pd.read_csv("basic_info.csv")
# Out:
#             id       recipe_name    rating  vote_number  prep_time  cook_time  \
# 0  66102450266  Black Magic Cake  4.767734         1786         15         35
#
#    total_time                                                url
# 0          60  http://allrecipes.com/recipe/8372/black-magic-...
#
# [1 rows x 8 columns]

# %%
pd.read_csv("ingredient_info.csv")
# Out:
#              id                        ingredient
# 0   66102450266      1 3/4 cups all-purpose flour
# 1   66102450266                2 cups white sugar
# 2   66102450266  3/4 cup unsweetened cocoa powder
# 3   66102450266           2 teaspoons baking soda
# 4   66102450266          1 teaspoon baking powder
# 5   66102450266                   1 teaspoon salt
# 6   66102450266                            2 eggs
# 7   66102450266        1 cup strong brewed coffee
# 8   66102450266                  1 cup buttermilk
# 9   66102450266             1/2 cup vegetable oil
# 10  66102450266        1 teaspoon vanilla extract
#
# [11 rows x 2 columns]

# %% [markdown]
# # 我們已經能抓取一個頁面了！
# 現在我們要來抓取多道食譜了！

# %% [markdown]
# # robots.txt
# * 通常告訴了爬蟲程式他們對爬蟲程式做了什麼限制
# * 因此當我們需要進行大量抓取資料時，不仿從這邊先看一下網站對crawler有什麼限制
# * 這樣子IP才比較不容易被BAN掉喔！

# %%
print requests.get("http://allrecipes.com/robots.txt").content
# Out:
# User-agent: *
# Disallow: /my/
# Disallow: /search/
# Disallow: /account/
# Disallow: /error/
# Disallow: /admin/
#
# User-agent: Slurp
# Crawl-delay: .05
#
# User-agent: 008
# Disallow: /

# %% [markdown]
# # 抓取多道食譜
# 進入主頁面後，我們將視窗往下拉到底，觀察一下主頁面 [http://allrecipes.com/recipes/79/desserts/?](http://allrecipes.com/recipes/79/desserts/?) <br>
# 當更新的符號結束後，可以看到網頁多了一個page的參數！
# ![](res/ajax.jpg)

# %% [markdown]
# # 讓我們來試抓個5頁吧！

# %%
def get_recipes(page_size):
    url_head = "http://allrecipes.com"
    url_format = "http://allrecipes.com/recipes/79/desserts/?page={page}#{page}"
    pages = [ requests.get(url_format.format(page=i)) for i in xrange(page_size) ]
    recipes_urls = [ url.get('href') for page in pages for url in BeautifulSoup(page.content).find_all('a') ]
    # 去掉不要的參數，去掉不合理的網址
    recipes_urls = [ "{0}{1}".format(url_head,url.split("?")[0]) for url in recipes_urls if url != None and url[:7] == '/recipe' and url[:8] != '/recipes']
    # 去掉重複的頁面
    recipes_urls = list(set(recipes_urls))
    return recipes_urls

# %%
recipes_urls = get_recipes(5)
print "Number of links:", len(recipes_urls)
parsed_results = [ parse_a_recipe(url,get_recipe_html(url)) for url in recipes_urls ]
output_csv(parsed_results)
# Out:
# Number of links: 89

# %%
pd.read_csv("basic_info.csv")
# Out:
#              id                                  recipe_name    rating  \
# 0   66102450266                                   Cake Balls  4.255517
# 1   66102450266          Whipped Cream Cream Cheese Frosting  4.716981
# 2   66102450266                      Too Much Chocolate Cake  4.773054
# 3   66102450266                           Easy Lemon Cookies  4.580826
# 4   66102450266                    Grandma Ople's  Apple Pie  4.796273
# 5   66102450266                               Apple Slab Pie  4.508772
# 56  66102450266                            MMMMM... Brownies  4.549296
# 57  66102450266                           Sweet Potato Pie I  4.785524
# 58  66102450266                        Chewy Coconut Cookies  4.674101
# 59  66102450266                             Black Magic Cake  4.767734
#             ...                                          ...       ...
#
#     vote_number  prep_time  cook_time  total_time  \
# 0          1852         40         30         190
# 1          1280         15        NaN          15
# 2          4636        NaN        NaN         NaN
# 3          1139        NaN        NaN         NaN
# 4          1866         30         60          90
# 5            43         30         60          90
# 6          1283         30         30          80
# 7          1554         30         18          75
# 8          1414        NaN        NaN         NaN
# 9          1090         15         15          60
# 10         1605         15          5          80
# 11         1592         30         60         150
# 12         2103         30        NaN         210
# 13         1911         20         30          60
# 14         1044         10          8          18
# 15         7070         20         10          60
# 16         1187         30         20          50
# 17         2444         20         30          50
# 18         1184        NaN        NaN         NaN
# 19         1945        NaN        NaN          90
# 20         1822         25        NaN          85
# 21         1656         15         10          25
# 22         6679         25         35          60
# 23         2224         15         30          45
# 24         1203        NaN        NaN         NaN
# 25         1277         15         10          60
# 26         2096         60         60         600
# 27          289         30         40         250
# 28         2733         15         10         120
# 29           16         10         35         165
# 30         1099         15        NaN         135
# 31         1436        NaN         15          25
# 32         3918         20         10          60
# 33         1560         30         25         535
# 34         7897         15         12         100
# 35         1731         15         40          65
# 36         1913         15         15          60
# 37          699         30         70         240
# 38         1719         10         20          30
# 39         3969         15         10          50
# 40         6742         20          8         180
# 41          171         45         20          65
# 42         1297         15         45         180
# 43         2063         15          8          55
# 44          186         30         80         110
# 45         2105         20         40          60
# 46         1149         15         10          60
# 47         2905         20         20          80
# 48           19         30         65         605
# 49         1302         15        NaN          15
# 50         3543         25         20          45
# 51         1491         30         35          65
# 52         3564         15         12          50
# 53         2837         15         35          50
# 54         2450         15         10          45
# 55         3202         15         12          55
# 56         1362         25         25          60
# 57         1765         30        110         140
# 58         1135         30         10          50
# 59         1786         15         35          60
#             ...        ...        ...         ...
#
#                                                   url
# 0      http://allrecipes.com/recipe/67656/cake-balls/
# 1   http://allrecipes.com/recipe/19108/whipped-cre...
# 2   http://allrecipes.com/recipe/7565/too-much-cho...
# 3   http://allrecipes.com/recipe/10776/easy-lemon-...
# 4   http://allrecipes.com/recipe/12377/grandma-opl...
# 5   http://allrecipes.com/recipe/19460/apple-slab-...
# 6   http://allrecipes.com/recipe/7736/dark-chocola...
# 7   http://allrecipes.com/recipe/10222/raspberry-a...
# 8   http://allrecipes.com/recipe/15295/soft-sugar-...
# 9   http://allrecipes.com/recipe/9996/chewy-peanut...
# 10  http://allrecipes.com/recipe/22724/easiest-pea...
# 11  http://allrecipes.com/recipe/8333/banana-cake-vi/
# 12  http://allrecipes.com/recipe/21398/banana-pudd...
# 13  http://allrecipes.com/recipe/17981/one-bowl-ch...
# 14  http://allrecipes.com/recipe/8236/satiny-choco...
# 15  http://allrecipes.com/recipe/10813/best-chocol...
# 16  http://allrecipes.com/recipe/10177/blonde-brow...
# 17  http://allrecipes.com/recipe/17481/simple-whit...
# 8   66102450266      1 (18.25 ounce) package devil's food cake mix
# 9   66102450266  1 (5.9 ounce) package instant chocolate puddin...
# 10  66102450266                                   1 cup sour cream
# 11  66102450266                                1 cup vegetable oil
# 12  66102450266                                             4 eggs
# 13  66102450266                                 1/2 cup warm water
# 14  66102450266                   2 cups semisweet chocolate chips
# 15  66102450266             1 (18.25 ounce) package lemon cake mix
# 16  66102450266                                             2 eggs
# 17  66102450266                              1/3 cup vegetable oil
# 18  66102450266                           1 teaspoon lemon extract
# 19  66102450266        1/3 cup confectioners' sugar for decoration
# 20  66102450266      1 recipe pastry for a 9 inch double crust pie
# 21  66102450266                            1/2 cup unsalted butter
# 22  66102450266                    3 tablespoons all-purpose flour
# 23  66102450266                                1/2 cup white sugar
# 24  66102450266                         1/2 cup packed brown sugar
# 25  66102450266                                      1/4 cup water
# 26  66102450266   8 Granny Smith apples - peeled, cored and sliced
# 27  66102450266                       1 1/2 cups all-purpose flour
# 28  66102450266                      1 1/2 tablespoons white sugar
# 29  66102450266                                 1/2 cup shortening
# 30  66102450266                                  1/4 teaspoon salt
# 31  66102450266                         1/2 teaspoon baking powder
# 32  66102450266                                2 egg yolks, beaten
# 33  66102450266                                4 tablespoons water
# 34  66102450266  8 apples - peeled, cored and cut into thin wedges
# 35  66102450266                          2 tablespoons lemon juice
# 36  66102450266                    2 tablespoons all-purpose flour
# 37  66102450266                             1 3/4 cups white sugar
# 38  66102450266                       1/2 teaspoon ground cinnamon
# 39  66102450266                               2 tablespoons butter
# 40  66102450266                            1 cup all-purpose flour
# 41  66102450266                         1 teaspoon ground cinnamon
# 42  66102450266                                2/3 cup brown sugar
# 43  66102450266                                     2/3 cup butter
# 44  66102450266                               2 cups boiling water
# 45  66102450266                     1 cup unsweetened cocoa powder
# 46  66102450266                       2 3/4 cups all-purpose flour
# 47  66102450266                            2 teaspoons baking soda
# 48  66102450266                         1/2 teaspoon baking powder
# 49  66102450266                                  1/2 teaspoon salt
# 50  66102450266                             1 cup butter, softened
# 51  66102450266                             2 1/4 cups white sugar
# 52  66102450266                                             4 eggs
# 53  66102450266                    1 1/2 teaspoons vanilla extract
# 54  66102450266                             1 cup butter, softened
# 55  66102450266                                2/3 cup white sugar
# 56  66102450266                        1/2 teaspoon almond extract
# 57  66102450266                           2 cups all-purpose flour
# 58  66102450266                     1/2 cup seedless raspberry jam
# 59  66102450266                       1/2 cup confectioners' sugar
#             ...                                                ...
#
# [835 rows x 2 columns]

# %% [markdown]
# # 4. A little summary
# ### so far ... 我們主要定義了3個function
# 1. get_recipes
#  * 找出了要抓取的食譜網頁
# 2. parse_a_recipe
#  * parse了要分析的食譜網頁
# 3. output_csv
#  * 將整理好的json檔案輸出成了2個csv檔
#
# ### 另外，requests則是擔任了downloader的角色

# %% [markdown]
# # 所以我們所做的事也可以整理成以下架構圖
# * Data Center: output_csv
# * Web Connector: requests
# * Data Parser: get_recipes, parse_a_recipe
#
# ![](res/spider_arch.png)

# %% [markdown]
# # Scrapy
# 知名的python crawler framwork Scrapy，其架構則更加豐富與複雜 <br>
# 一方面幫我們做好了很多複雜的功能，ex 續傳功能 <br>
# 因此如果需要寫比較大型的crawler的話，推薦可以研究看看scrapy <br>
# 但如果是要寫一個小crawler的話，其實簡單搭配requests 跟 beautiful soup就可以了！ <br>
#
# ![](res/scrapy_arch.png)

# %% [markdown]
# # 5. Practice
# ### Now is your turn!
# * 請大家依照下列4個步驟來寫一個ptt crawler抓取ptt八卦版吧！ <br>
# * 八卦版網址: [https://www.ptt.cc/bbs/Gossiping/](https://www.ptt.cc/bbs/Gossiping/)
#     1. 抓出每一篇po文的link(抓取5個頁面即可)
#     2. 抓取各頁面
#     3. parse資料成json
#     4. 整理資料輸出成ptt.csv
#
# * 需要留下的欄位有...
#
# |   |     說明      |       欄位       |  範例  |
# |---|--------------|------------------|------|
# | 1.| po文是否被推爆 | overpush         | True or False |
# | 2.| po文網址      | url              | https://www.ptt.cc/bbs/Gossiping/M.1119534821.A.8B6.html |
# | 3.| po文作者      | author           | benjamin0126 (LaNew衝五連勝吧) |
# | 4.| po文標題      | title            | 有那些藝人有高學歷 |
# | 5.| po文時間      | author_post_time | Thu Jun 23 21:56:57 2005 |
# | 6.| 推文帳號      | reviewer         | Armando |
# | 7.| 推文內容      | review_content   | 哈佛中文 ...是在幹麻?  到外國學中文 |
# | 8.| 推文時間      | review_time      | 06/23 |
# | 9.| 推虛          | review_status    | 推 |

# %%
print requests.get("http://www.ptt.cc/bbs/Gossiping/index1.html").content
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-120-b0e2ab5fa591> in <module>()
# ----> 1 print requests.get("http://www.ptt.cc/bbs/Gossiping/index1.html").content
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     381             'allow_redirects': allow_redirects,
#     382         }
# --> 383         resp = self.send(prep, **send_kwargs)
#     384
#     385         return resp
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/sessions.pyc in send(self, request, **kwargs)
#     504
#     505         # Resolve redirects if allowed.
# --> 506         history = [resp for resp in gen] if allow_redirects else []
#     507
#     508         # Shuffle things around if there's history.
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/sessions.pyc in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies)
#     166                 cert=cert,
#     167                 proxies=proxies,
# --> 168                 allow_redirects=False,
#     169             )
#     170
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/sessions.pyc in send(self, request, **kwargs)
#     484         start = datetime.utcnow()
#     485         # Send the request
# --> 486         r = adapter.send(request, **kwargs)
#     487         # Total elapsed time of the request (approximately)
#     488         r.elapsed = datetime.utcnow() - start
#
# /Library/Python/2.7/site-packages/requests-2.2.1-py2.7.egg/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     383         except (_SSLError, _HTTPError) as e:
#     384             if isinstance(e, _SSLError):
# --> 385                 raise SSLError(e)
#     386             elif isinstance(e, TimeoutError):
#     387                 raise Timeout(e)
#
# SSLError: hostname 'www.ptt.cc' doesn't match either of 'images.ptt.cc', 'ptt.cc'

# %% [markdown]
# # Hint
# 由於連線憑證的關係，請求傳送時，需加入verify=False的參數取消憑證

# %%
print requests.get("http://www.ptt.cc/bbs/Gossiping/index1.html",verify=False).content
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/pushstream.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-print.css" media="print" />
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.13/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <img class="over18-notice" src="//images.ptt.cc/v2.13/ticrf_r_red_n.gif" width="120" height="187">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>根據「電腦網路內容分級處理辦法」第六條第三款規定，本網站已於各限制級網頁依照台灣網站分級推廣基金會之規定標示。
#         若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index1.html">
#         <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#     </form>
# </div>
#
#     </body>
# </html>

# %% [markdown]
# # 想看八卦怎麼辦呢???
# ![](res/pttR18.png)

# %% [markdown]
# 1. 開啟chrome，按右鍵"檢視元素"
# 2. 點選network
# 3. 點選我同意，觀察傳送的封包，會有一個over18，裏頭向https://www.ptt.cc/ask/over18 post了參數
# ![](res/over18.png)
#
# 4. 檢查傳送的參數中，會發現他設定了一個cookie，裏頭設定了from跟yes
#
# ![](res/from_data.png)

# %% [markdown]
# # requests.session()
# 為了能夠紀錄住已經通過的驗證，我們必須使用session來記錄狀態

# %%
s = requests.session()
cookie = {
    "from": "/bbs/Gossiping/index.html",
    "yes": "yes"
}
s.post("https://www.ptt.cc/ask/over18",verify=False,data=cookie)
result = s.get("https://www.ptt.cc/bbs/Gossiping/index.html",verify=False)
print result.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/pushstream.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-print.css" media="print" />
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.13/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group pull-right">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index10328.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448561847.A.144.html">[問卦] 有沒有兩個月亮會怎樣的八卦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">Zawar379</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562071.A.29F.html">[新聞] 土總統：若知是俄機 可能不會擊落</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">GuoJia</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562247.A.7CF.html">[問卦] 有沒有愛上不可能有結果的人的八卦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">funnypeter</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(本文已被刪除) [lturtsamuel]
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562464.A.E1D.html">Re: [新聞] 中國學者驚語：校園是gay產生的「重災區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">velvetavt</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">7</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562474.A.C4E.html">Re: [問卦] 眷村子弟會覺醒嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">tommy1014</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562512.A.60D.html">Re: [問卦] 認真思考自己死亡這件事情</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">s3602te</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">7</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562571.A.F8C.html">[問卦] 半夜就能把車開上高鐵站行人區拍照?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">FECer</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562831.A.128.html">Re: [問卦] 哀鳳的sim卡大小</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">stan1231</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">15</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448562833.A.48C.html">[問卦] 台灣服務業是否太好過頭??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">hk416</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448563206.A.805.html">Re: [問卦] 台灣收入，美國等級消費，這是甚麼道理呢</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">fluterway</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448563301.A.75E.html">Re: [新聞] 邱顯智籲柯建銘效法柯P 打場理念之戰</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">acont</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448563424.A.483.html">Re: [問卦] 台外資撤離中國，中共如何應對失業增加?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">takase</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448563642.A.78E.html">Re: [問卦] 關於陸生健保的幾件事</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">atorneychien</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448563895.A.FA9.html">[問卦] 滿漢大餐VS一度贊誰才是牛肉麵一哥?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">SpadeR</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">12</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448564327.A.4CF.html">[問卦] 有沒有在醫院照顧家人要做什麼的八卦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">Jetrel</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448564526.A.906.html">[新聞] 德國「參戰」　偵察機、護衛艦助法攻IS</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">coon182</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448564642.A.273.html">Re: [問卦] 關於陸生健保的幾件事</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">nickyang</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448564664.A.8CE.html">[問卦] 上班用鞋款中的霸主是?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/27</div>
# 				<div class="author">qsef5</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1434384024.A.711.html">[公告] 八卦板板規(2015.06.16)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/16</div>
# 				<div class="author">seabox</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">9</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448284729.A.C8A.html">[公告] 數條板規修改草案於GossipPicket討論</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/23</div>
# 				<div class="author">seabox</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">12</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448357008.A.298.html">[徵求] 死亡車禍 徵求行車紀錄器影像-科學園區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/24</div>
# 				<div class="author">fifteengrain</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1448385769.A.235.html">[協尋] 11/24 早上九點 國一南崁交流道死亡車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">11/25</div>
# 				<div class="author">LinIsGod</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">15</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1446296399.A.9E6.html">[公告] 十一月份置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">10/31</div>
# 				<div class="author">meowmeowgo</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#     </body>
# </html>

# %% [markdown]
# # 接下來只要使用S來get，並記得verify設為False就可以正常抓取網頁了！

# %% [markdown]
# # 1. 抓出每一篇po文的link
# 並順便抓出是否推爆

# %%
def extract_post_page_url(start_page,end_page):
    url_format = "https://www.ptt.cc/bbs/Gossiping/index{index}.html"
    head = "https://www.ptt.cc"
    post_page_urls = []
    for i in xrange(start_page,end_page):
        url = url_format.format(index=i)
        page_list = BeautifulSoup(s.get(url,verify=False).content).find_all('div',class_="r-ent")
        post_page_urls.extend([ ("{0}{1}".format(head,page.find('a').get('href')),page) for page in page_list ])
    return list(set(post_page_urls))

# %%
post_page_url = extract_post_page_url(3,5)
print len(post_page_url)
# Out:
# 40

# %% [markdown]
# # 2. 抓取各頁面

# %%
def download_pages(urls):
    return [ (url,overpush,BeautifulSoup(s.get(url,verify=False).content)) for url,overpush in urls ]

# %%
pages = download_pages(post_page_url)

# %% [markdown]
# # 3. parse資料成json
# |   |     說明      |       欄位       |  範例  |
# |---|--------------|------------------|------|
# | 1.| po文是否被推爆 | overpush         | True or False |
# | 2.| po文網址      | url              | https://www.ptt.cc/bbs/Gossiping/M.1119534821.A.8B6.html |
# | 3.| po文作者      | author           | benjamin0126 (LaNew衝五連勝吧) |
# | 4.| po文標題      | title            | 有那些藝人有高學歷 |
# | 5.| po文時間      | author_post_time | Thu Jun 23 21:56:57 2005 |
# | 6.| 推文帳號      | reviewer         | Armando |
# | 7.| 推文內容      | review_content   | 哈佛中文 ...是在幹麻?  到外國學中文 |
# | 8.| 推文時間      | review_time      | 06/23 |
# | 9.| 推虛          | review_status    | 推 |

# %%
def extract_review(review,class_):
    return review.find("span",class_=class_).get_text().encode("utf8")

def parser(pages):
    parsed_results = []
    for url,overpush,soup in pages:
        try:
            overpush = overpush.find('span',class_="hl")
            tmp_parsed_result = {
                "overpush": True if overpush != None and overpush.get_text().encode("utf8") == '爆' else False,
                "url": url,
                "reviewer": [],
                "review_content": [],
                "review_time": [],
                "review_status": []
            }
            article_meta_line = soup.find_all("div",class_="article-metaline")
            tmp_parsed_result['author'] = article_meta_line[0].find('span',class_="article-meta-value").get_text().encode("utf8")
            tmp_parsed_result['title'] = article_meta_line[1].find('span',class_="article-meta-value").get_text().encode("utf8")
            tmp_parsed_result['author_post_time'] = article_meta_line[2].find('span',class_="article-meta-value").get_text().encode("utf8")
            for review in soup.find_all("div",class_="push"):
                if review.get_text().encode("utf8") == "檔案過大！部分文章無法顯示":
                    continue
                tmp_parsed_result['reviewer'].append( extract_review(review,"push-userid") )
                tmp_parsed_result['review_content'].append( extract_review(review,"push-content") )
                tmp_parsed_result['review_time'].append( extract_review(review,"push-ipdatetime") )
                tmp_parsed_result['review_status'].append( extract_review(review,"push-tag") )
            parsed_results.append(tmp_parsed_result)
        except:
            print soup
    return parsed_results

# %%
parsed_results = parser(pages)

# %% [markdown]
# # 4. 整理資料輸出成ptt.csv

# %%
def output_ptt_csv(parsed_results):
    order = ['overpush','url','author','title','author_post_time','reviewer','review_content','review_time','review_status']
    writer = open("ptt.csv",'w')
    writer.write('"'+'","'.join(order)+'"\n')
    for parsed_result in parsed_results:
        tmp_raw = '"'+'","'.join([ str(parsed_result[o]) for o in order[:5] ])+'"'
        for i in xrange(len(parsed_result['reviewer'])):
            writer.write( '{0},"{1}"\n'.format(tmp_raw,'","'.join([ str(parsed_result[o][i]) for o in order[5:] ])) )
    writer.close()

# %%
output_ptt_csv(parsed_results)

# %%
pd.read_csv("ptt.csv")
# Out:
#    overpush                                                url  \
# 0     False  https://www.ptt.cc/bbs/Gossiping/M.1119650484....
# 1     False  https://www.ptt.cc/bbs/Gossiping/M.1119650484....
# 2     False  https://www.ptt.cc/bbs/Gossiping/M.1119650484....
# 3     False  https://www.ptt.cc/bbs/Gossiping/M.1119650484....
# 4     False  https://www.ptt.cc/bbs/Gossiping/M.1119650484....
# 5     False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 6     False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 7     False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 8     False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 9     False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 10    False  https://www.ptt.cc/bbs/Gossiping/M.1119622394....
# 11    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 12    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 13    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 14    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 15    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 16    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 17    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 18    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 19    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 20    False  https://www.ptt.cc/bbs/Gossiping/M.1119513779....
# 21    False  https://www.ptt.cc/bbs/Gossiping/M.1119425421....
# 3     stationery                               :她後來好像去拍華視的戲 忘了演什麼@@
# 4       loveices                                             :女生向錢走
# 5           zett                              :民航機內不是禁用手機嗎？ 怎麼會....
# 6           zett                                   :還是已知被劫機，才用手機聯絡？
# 7           ykao                                 :美國國內線我沒記錯的話是可以用電話
# 8           ykao                       :有些機上還有AT&T的刷卡電話機, 所以應該是可以打的
# 9    CRAZYDRAGON                            :Autobots! Let's roll!~
# 10       freeasy  : 911真相 https://www.youtube.com/watch?v=ZJi7fR...
# 11      censored                                      :是越南人不是大陸同胞吧?
# 12      peichuan                                        :我也記得好像是越南的
# 13   babiebeauty                                         :是越南（非常肯定）
# 14       gskindm                                 :那個電影也對我幼小的心靈造成衝擊啊
# 15       AnyTime                                              :是越南吧
# 16     wht810090                                   :更正確的說是被越共滅國的南越。
# 17       pase139                                               :推樓上
# 18         mOoOm                                              : ︿　︿
# 19         mOoOm                                          :\('00')/
# 20         mOoOm                                            : (.人.)
# 21        hahano                         :帥啊..有八卦到...可是可不可以仔細講下洗錢細節
# 22       MRkitty                                     :超強的八卦 雖然看不太懂啊
# 23    NymphVENUS                                          :據我所知的確如此
# 24           VOY                                         :推!好詳細的八卦!
# 25   engineering                                :出海關查退稅嚴格時 一項一項查耶..
# 26       cocytus                                   :對啊，洗錢部分我也看不懂@_@
# 27        talesr                           :洗錢應該就是把黑錢換成貨物 再拿到別的地方賣掉
# 28        talesr                                     :這樣就拿回現金  還有得賺
# 29        fatarm                             :黑錢不能直接會回去日本用，就換成LV回日本
# 30        fatarm                                    :LV銷路好，回日本賣變成現金
# 31    johhan1972                                     :推這八卦,內行的人才能知道
# 32       pink008                         :我去巴黎也被抓去代買...那個阿姨其實人不錯...
# 33       pink008                           :當時她是拿旅支出來,完全空白的,然後要我在上面
# 34       pink008                           :先簽上我的名字,可是後來,因為店員一直說沒貨,
# 35       pink008                          :所以旅支沒用完,我那時還想,我都簽名了,她要怎麼
# 36       pink008                        :解決剩下的300法郎?原來是洗錢,難怪她們不擔心!!
# 37       pink008                              :枉費我那時還覺得不好意思....>_<!
# 38       pink008                           :那阿姨還帶我們去買巴黎地鐵票(一週用隨便坐到哪
# 39         jruno                          :話說我剛從法國留學回來! 在我們留學生圈子都知道
# 40         jruno                          :如果在香榭大道附近遇到的都是大陸人!他們真的都會
# 41         jruno                        :要請你幫他們!我在那邊遇過n次了!都裝日本帶過...
# 42         jruno                             :也不要貪小便宜啦!也有人幫他們買被詐騙過!
# 43         jruno                          :真的要小心!在那邊大陸人的心真的很黑!為了錢他們
# 44         jruno                        :啥事都做的出來!我也問過LV了他們真的沒有限量...
# 45         jruno                           :你有錢的話買多少都可以!他們還開心的ㄌ....
# 46         jruno                          :還有推薦不要去拉法葉百貨公司買..去香榭大道那家
# 47         jruno                          :拉法葉的服務人員我覺得態度不好!都用法文偷罵顧客
# 48         jruno                            :超級機八!都以為別人聽不懂法文!超沒禮貌的!
# 49          ilcd                     :謝謝樓上的推文 剛好過一陣子要去    會注意的@@|||
# 50      philippe                             :至少要跟她談佣金啊，不要只拿5歐元，太少了
# 51   redbeanlisa                                           :好險我有黎沙…
# 52     god060119                                               : 真的
# 53     cloudbaby                                  :很順"的女歌手是......？"
# 54       ameifan                                              :順子??
# 55     Sukiyakii                                 :很順的女歌手 是在說筍子吧~~~~
# 56       ameifan                                      :我滿喜歡順子的歌聲的XD
# 57     marcusguo                                            :很高的樑女?
# 58       frolina                                              :梁GG?
# 59    fivesixOGC                                              :是雞雞吧
#              ...                                                ...
#
#                       review_time review_status
# 0            163.25.118.8 06/25\n            推
# 1            163.25.118.8 06/25\n            →
# 2          218.165.106.83 06/25\n            推
# 3            163.25.118.8 06/25\n            →
# 4          140.123.222.71 06/25\n            推
# 5           61.217.145.45 06/24\n            推
# 6           61.217.145.45 06/24\n            →
# 7            61.70.169.60 06/24\n            →
# 8            61.70.169.60 06/24\n            →
# 9                   11/26 12:16\n            推
# 10                  11/25 18:10\n            推
# 11           152.3.83.245 06/23\n            推
# 12         211.23.177.142 06/23\n            推
# 13           163.29.208.2 06/23\n            推
# 14         220.228.156.24 06/23\n            推
# 15         218.167.168.65 06/23\n            推
# 16           140.112.7.59 06/24\n            →
# 17     61.60.75.146 12/06 16:06\n            →
# 18                  07/24 08:59\n            推
# 19                  07/24 09:00\n            →
# 20                  07/24 09:00\n            →
# 21          61.230.41.210 06/22\n            推
# 22        140.112.214.200 06/22\n            推
# 23          218.166.86.43 06/22\n            推
# 24         203.204.40.174 06/22\n            推
# 25          61.62.195.186 06/22\n            →
# 26          59.115.17.142 06/22\n            →
# 27        218.162.169.169 06/22\n            推
# 28        218.162.169.169 06/22\n            →
# 29          61.230.76.223 06/22\n            推
# 30          61.230.76.223 06/22\n            →
# 31        210.202.245.129 06/22\n            推
# 32         218.169.235.88 06/22\n            推
# 33         218.169.235.88 06/22\n            →
# 34         218.169.235.88 06/22\n            →
# 35         218.169.235.88 06/22\n            →
# 36         218.169.235.88 06/22\n            →
# 37         218.169.235.88 06/22\n            →
# 38         218.169.235.88 06/22\n            推
# 39        218.172.159.185 06/22\n            推
# 40        218.172.159.185 06/22\n            →
# 41        218.172.159.185 06/22\n            →
# 42        218.172.159.185 06/22\n            →
# 43        218.172.159.185 06/22\n            →
# 44        218.172.159.185 06/22\n            →
# 45        218.172.159.185 06/22\n            →
# 46        218.172.159.185 06/22\n            →
# 47        218.172.159.185 06/22\n            →
# 48        218.172.159.185 06/22\n            →
# 49         218.167.152.67 06/22\n            推
# 50         219.81.158.171 06/22\n            →
# 51                  06/19 12:09\n            噓
# 52                  08/27 14:19\n            噓
# 53         61.222.119.200 06/23\n            推
# 54         210.192.168.48 06/23\n            推
# 55          220.137.92.81 06/23\n            推
# 56         210.192.168.48 06/23\n            →
# 57          61.64.118.172 06/23\n            推
# 58         140.119.146.69 06/23\n            推
# 59          140.121.193.9 06/23\n            推
#                               ...           ...
#
# [1199 rows x 9 columns]

# %% [markdown]
# # Thanks for your watching!
